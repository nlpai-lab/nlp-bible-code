# %% [markdown]
# # Code download

# %%
# !git clone 'https://github.com/dongjun-Lee/text-summarization-tensorflow.git'
# Out:
# Cloning into 'text-summarization-tensorflow'...
# remote: Enumerating objects: 48, done.
# remote: Total 48 (delta 0), reused 0 (delta 0), pack-reused 48
# Unpacking objects: 100% (48/48), done.

# %% [markdown]
# **Setting**

# %%
cd ./text-summarization-tensorflow/
# Out:
# /content/text-summarization-tensorflow

# %%
# !pip install -r requirements.txt
# Out:
# Collecting gensim==3.3.0
#   Downloading https://files.pythonhosted.org/packages/0c/50/b3ea3db5ce57b215d88e58d64e32924596e78f35bdfa229735a1ee1e86cb/gensim-3.3.0-cp36-cp36m-manylinux1_x86_64.whl (22.5MB)
#      |████████████████████████████████| 22.5MB 135kB/s
# Collecting wget==3.2
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Requirement already satisfied: nltk==3.2.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (3.2.5)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim==3.3.0->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim==3.3.0->-r requirements.txt (line 1)) (1.17.5)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim==3.3.0->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim==3.3.0->-r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: boto>=2.32 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim==3.3.0->-r requirements.txt (line 1)) (2.49.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim==3.3.0->-r requirements.txt (line 1)) (1.11.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim==3.3.0->-r requirements.txt (line 1)) (2.21.0)
# Requirement already satisfied: botocore<1.15.0,>=1.14.15 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim==3.3.0->-r requirements.txt (line 1)) (1.14.15)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim==3.3.0->-r requirements.txt (line 1)) (0.9.4)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim==3.3.0->-r requirements.txt (line 1)) (0.3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim==3.3.0->-r requirements.txt (line 1)) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim==3.3.0->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim==3.3.0->-r requirements.txt (line 1)) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim==3.3.0->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.15.0,>=1.14.15->boto3->smart-open>=1.2.1->gensim==3.3.0->-r requirements.txt (line 1)) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.15.0,>=1.14.15->boto3->smart-open>=1.2.1->gensim==3.3.0->-r requirements.txt (line 1)) (2.6.1)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=ed0dc8e9a7fff124d4fdfc2e5597f88e04830b8c218a9e02cfab52dd67fe33c4
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: gensim, wget
#   Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-3.3.0 wget-3.2

# %% [markdown]
# ## Data download

# %% [markdown]
# [data url](https://drive.google.com/open?id=0B6N7tANPyVeBNmlSX19Ld2xDU1E)

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=0B6N7tANPyVeBNmlSX19Ld2xDU1E' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=0B6N7tANPyVeBNmlSX19Ld2xDU1E" -O summary.tar.gz && rm -rf /tmp/cookies.txt
# Out:
# --2020-02-28 00:16:31--  https://docs.google.com/uc?export=download&confirm=9vbh&id=0B6N7tANPyVeBNmlSX19Ld2xDU1E
# Resolving docs.google.com (docs.google.com)... 172.217.218.101, 172.217.218.138, 172.217.218.113, ...
# Connecting to docs.google.com (docs.google.com)|172.217.218.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0o-ac-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/08itu6k64l2hiusk7ntgjio93bigugid/1582848975000/03129501499031348422/*/0B6N7tANPyVeBNmlSX19Ld2xDU1E?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-02-28 00:16:31--  https://doc-0o-ac-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/08itu6k64l2hiusk7ntgjio93bigugid/1582848975000/03129501499031348422/*/0B6N7tANPyVeBNmlSX19Ld2xDU1E?e=download
# Resolving doc-0o-ac-docs.googleusercontent.com (doc-0o-ac-docs.googleusercontent.com)... 108.177.119.132, 2a00:1450:4013:c00::84
# Connecting to doc-0o-ac-docs.googleusercontent.com (doc-0o-ac-docs.googleusercontent.com)|108.177.119.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/gzip]
# Saving to: ‘summary.tar.gz’
#
# summary.tar.gz          [             <=>    ] 277.39M  65.6MB/s    in 4.2s
#
# 2020-02-28 00:16:37 (65.6 MB/s) - ‘summary.tar.gz’ saved [290866023]

# %% [markdown]
# ## Prepare data

# %%
# !python prep_data.py

# %%
import os
import zipfile 

glove_dir = "glove"
if not os.path.exists(glove_dir):
        os.mkdir(glove_dir)

# !EXPORT $glove_url = "https://nlp.stanford.edu/data/wordvecs/glove.42B.300d.zip"
# Download glove vector
# !wget $glove_url -O glove/glove.42B.300d.zip
# Out:
# /bin/bash: EXPORT: command not found
# --2020-02-28 00:28:21--  https://nlp.stanford.edu/data/wordvecs/glove.42B.300d.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/wordvecs/glove.42B.300d.zip [following]
# --2020-02-28 00:28:21--  http://downloads.cs.stanford.edu/nlp/data/wordvecs/glove.42B.300d.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1877802108 (1.7G) [application/zip]
# Saving to: ‘glove/glove.42B.300d.zip’
#
# glove/glove.42B.300 100%[===================>]   1.75G  2.17MB/s    in 14m 34s
#
# 2020-02-28 00:42:56 (2.05 MB/s) - ‘glove/glove.42B.300d.zip’ saved [1877802108/1877802108]

# %%
# Extract glove file
with zipfile.ZipFile(os.path.join("glove", "glove.42B.300d.zip"), "r") as z:
# with zipfile.ZipFile("glove.42B.300d.zip", "r") as z:
  z.extractall(glove_dir)

# %% [markdown]
# # Train

# %%
# We used sumdata/train/train.article.txt and sumdata/train/train.title.txt for training data. To train the model, use
# !python train.py
# Out:
# Building dictionary...
#
# ^C

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# To use Glove pre-trained vectors as initial embedding, use
# !python train.py --glove --num_epochs=2
# Out:
# Building dictionary...
# tcmalloc: large alloc 1233903616 bytes == 0x50988000 @  0x7f50e70df615 0x5793c5 0x50a94c 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50b403 0x635222 0x6352d7 0x638a8f 0x639631 0x4b0f40 0x7f50e6cdbb97 0x5b2fda
# tcmalloc: large alloc 1542381568 bytes == 0x9a246000 @  0x7f50e70df615 0x5793c5 0x50a94c 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50b403 0x635222 0x6352d7 0x638a8f 0x639631 0x4b0f40 0x7f50e6cdbb97 0x5b2fda
# Loading training dataset...
# WARNING:tensorflow:From train.py:52: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-02-28 05:03:00.985363: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-02-28 05:03:01.013601: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-28 05:03:01.014373: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-02-28 05:03:01.026796: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-02-28 05:03:01.270761: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-02-28 05:03:01.406755: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-02-28 05:03:01.428276: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-02-28 05:03:01.703354: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-02-28 05:03:01.731964: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-02-28 05:03:02.228868: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-02-28 05:03:02.229102: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-28 05:03:02.229872: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-28 05:03:02.230468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-02-28 05:03:02.231149: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-02-28 05:03:02.238677: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000155000 Hz
# 2020-02-28 05:03:02.239025: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x324d640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-02-28 05:03:02.239057: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-02-28 05:03:02.331578: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-28 05:03:02.332083: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x324d480 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-02-28 05:03:02.332111: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-02-28 05:03:02.332429: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-28 05:03:02.332816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-02-28 05:03:02.332909: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-02-28 05:03:02.332948: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-02-28 05:03:02.332975: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-02-28 05:03:02.333004: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-02-28 05:03:02.333026: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-02-28 05:03:02.333047: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-02-28 05:03:02.333069: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-02-28 05:03:02.333146: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-28 05:03:02.333576: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-28 05:03:02.333933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-02-28 05:03:02.334074: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-02-28 05:03:02.335477: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-02-28 05:03:02.335509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-02-28 05:03:02.335521: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-02-28 05:03:02.335683: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-28 05:03:02.336135: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-28 05:03:02.336598: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-02-28 05:03:02.336715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# WARNING:tensorflow:From /content/text-summarization-tensorflow/model.py:19: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/text-summarization-tensorflow/model.py:20: The name tf.layers.Dense is deprecated. Please use tf.compat.v1.layers.Dense instead.
#
# WARNING:tensorflow:From /content/text-summarization-tensorflow/model.py:22: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# Loading Glove vectors...
# tcmalloc: large alloc 2301001728 bytes == 0x17246000 @  0x7f50e70e0001 0x7f50e45550f5 0x7f50e45b84d9 0x7f50e45ba6af 0x7f50e46509b8 0x50ac25 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x5096b7 0x595311 0x54a6ff 0x551b81 0x5aa6ec 0x50abb3 0x50c5b9 0x508245 0x50b403 0x635222 0x6352d7 0x638a8f
# WARNING:tensorflow:From /content/text-summarization-tensorflow/model.py:35: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/text-summarization-tensorflow/model.py:40: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/rnn/python/ops/rnn.py:239: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:735: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/text-summarization-tensorflow/model.py:101: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/text-summarization-tensorflow/model.py:103: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /content/text-summarization-tensorflow/model.py:106: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:54: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2020-02-28 05:16:39.291250: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 147160800 exceeds 10% of system memory.
# 2020-02-28 05:16:39.353557: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 147160800 exceeds 10% of system memory.
# 2020-02-28 05:16:39.410679: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 147160800 exceeds 10% of system memory.
# 2020-02-28 05:16:39.443213: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 147160800 exceeds 10% of system memory.
# 2020-02-28 05:16:39.474685: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 147160800 exceeds 10% of system memory.
# WARNING:tensorflow:From train.py:55: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:55: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
#
# Iteration starts.
# Number of batches per epoch : 59437
# 2020-02-28 05:17:06.957786: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# step 1000: loss = 49.19172668457031
# step 2000: loss = 37.12776184082031
# step 3000: loss = 35.713600158691406
# step 4000: loss = 34.15208435058594

# %% [markdown]
# **Additional parameters**

# %%
# !python train.py -h
# usage: train.py [-h] [--num_hidden NUM_HIDDEN] [--num_layers NUM_LAYERS]
#                 [--beam_width BEAM_WIDTH] [--glove]
#                 [--embedding_size EMBEDDING_SIZE]
#                 [--learning_rate LEARNING_RATE] [--batch_size BATCH_SIZE]
#                 [--num_epochs NUM_EPOCHS] [--keep_prob KEEP_PROB] [--toy]

# optional arguments:
#   -h, --help            show this help message and exit
#   --num_hidden NUM_HIDDEN
#                         Network size.
#   --num_layers NUM_LAYERS
#                         Network depth.
#   --beam_width BEAM_WIDTH
#                         Beam width for beam search decoder.
#   --glove               Use glove as initial word embedding.
#   --embedding_size EMBEDDING_SIZE
#                         Word embedding size.
#   --learning_rate LEARNING_RATE
#                         Learning rate.
#   --batch_size BATCH_SIZE
#                         Batch size.
#   --num_epochs NUM_EPOCHS
#                         Number of epochs.
#   --keep_prob KEEP_PROB
#                         Dropout keep prob.
#   --toy                 Use only 5K samples of data

# %% [markdown]
# **Test**

# %%
# !python test.py
